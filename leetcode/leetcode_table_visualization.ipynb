# %%
import json
import pandas as pd
def table_to_df(table_str):
    table = json.loads(table_str)
    df = pd.DataFrame(table['values'], columns=table['headers'])
    return df

# %%
table_to_df('{"headers":["Id","Client_Id","Driver_Id","City_Id","Status","Request_at","Users_Id","Banned","Role","Users_Id","Banned","Role"],"values":[[1,1,10,1,"completed","2013-10-01",1,"No","client",10,"No","driver"],[5,1,10,1,"completed","2013-10-02",1,"No","client",10,"No","driver"],[9,3,10,12,"completed","2013-10-03",3,"No","client",10,"No","driver"],[2,2,11,1,"cancelled_by_driver","2013-10-01",null,null,null,11,"No","driver"],[6,2,11,6,"completed","2013-10-02",null,null,null,11,"No","driver"],[3,3,12,6,"completed","2013-10-01",3,"No","client",12,"No","driver"],[7,3,12,6,"completed","2013-10-02",3,"No","client",12,"No","driver"],[8,2,12,12,"completed","2013-10-03",null,null,null,12,"No","driver"],[4,4,13,6,"cancelled_by_client","2013-10-01",4,"No","client",13,"No","driver"],[10,4,13,12,"cancelled_by_driver","2013-10-03",4,"No","client",13,"No","driver"]]}')
# Out:
#    Id  Client_Id  Driver_Id  City_Id               Status  Request_at  \
# 0   1          1         10        1            completed  2013-10-01
# 1   5          1         10        1            completed  2013-10-02
# 2   9          3         10       12            completed  2013-10-03
# 3   2          2         11        1  cancelled_by_driver  2013-10-01
# 4   6          2         11        6            completed  2013-10-02
# 5   3          3         12        6            completed  2013-10-01
# 6   7          3         12        6            completed  2013-10-02
# 7   8          2         12       12            completed  2013-10-03
# 8   4          4         13        6  cancelled_by_client  2013-10-01
# 9  10          4         13       12  cancelled_by_driver  2013-10-03
#
#    Users_Id Banned    Role  Users_Id Banned    Role
# 0       1.0     No  client        10     No  driver
# 1       1.0     No  client        10     No  driver
# ...

# %%
table_to_df('{"headers":["Id","Client_Id","Driver_Id","City_Id","Status","Request_at","Users_Id","Banned","Role","Users_Id","Banned","Role"],"values":[[1,1,10,1,"completed","2013-10-01",1,"No","client",10,"No","driver"],[3,3,12,6,"completed","2013-10-01",3,"No","client",12,"No","driver"],[4,4,13,6,"cancelled_by_client","2013-10-01",4,"No","client",13,"No","driver"],[5,1,10,1,"completed","2013-10-02",1,"No","client",10,"No","driver"],[7,3,12,6,"completed","2013-10-02",3,"No","client",12,"No","driver"],[9,3,10,12,"completed","2013-10-03",3,"No","client",10,"No","driver"],[10,4,13,12,"cancelled_by_driver","2013-10-03",4,"No","client",13,"No","driver"]]}')
# Out:
#    Id  Client_Id  Driver_Id  City_Id               Status  Request_at  \
# 0   1          1         10        1            completed  2013-10-01
# 1   3          3         12        6            completed  2013-10-01
# 2   4          4         13        6  cancelled_by_client  2013-10-01
# 3   5          1         10        1            completed  2013-10-02
# 4   7          3         12        6            completed  2013-10-02
# 5   9          3         10       12            completed  2013-10-03
# 6  10          4         13       12  cancelled_by_driver  2013-10-03
#
#    Users_Id Banned    Role  Users_Id Banned    Role
# 0         1     No  client        10     No  driver
# 1         3     No  client        12     No  driver
# 2         4     No  client        13     No  driver
# 3         1     No  client        10     No  driver
# 4         3     No  client        12     No  driver
# 5         3     No  client        10     No  driver
# ...
